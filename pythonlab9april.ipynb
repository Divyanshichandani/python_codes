# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshichandani/python_codes/blob/main/pythonlab9april.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''define a class named shape and its subclass square. the square class has an
init function which takes a length as an argument.
 both classes have an area function which can print the area
 of the shape where shape's area is 0 by default'''

class Shape:
  def __init__(self):
    pass

  def area(self):
    print("Area of the shape is 0")

class Square(Shape):
  def __init__(self, length):
    super().__init__()
    self.length = length

  def area(self):
    print("Area of the square is", self.length * self.length)

shape = Shape()
square = Square(6)

shape.area()
square.area()
# Out:
# Area of the shape is 0
# Area of the square is 36

# %%
'''define a class named shape and its subclass square. the square class
 has an init function which takes a length as an argument.
 both classes have an area function which can print the area of t
 he shape where shape's area is 0 by default'''


from abc import ABC, abstractmethod

class Employee(ABC):
  """Abstract class representing an employee."""

  @abstractmethod
  def name(self):
    """Returns the employee's name."""
    pass

  @abstractmethod
  def email(self):
    """Returns the employee's email address."""
    pass

  @abstractmethod
  def sap_id(self):
    """Returns the employee's SAP ID."""
    pass

class Professor(Employee):
  """Concrete class representing a professor."""

  def __init__(self, name, email, sap_id):
    self.name = name
    self.email = email
    self.sap_id = sap_id

  def name(self):
    return self.name

  def email(self):
    return self.email

  def sap_id(self):
    return self.sap_id

# Create a professor instance
professor = Professor("divyanshi", "divyanshi.123943@stu.upes.ac.in", "123943")

print(professor.name)
print(professor.email)
print(professor.sap_id)
# Out:
# divyanshi
# divyanshi.123943@stu.upes.ac.in
# 123943

# %%
'''create a circle constructor that creates a circle with a radius
 provided as an argument.the circle constructed must have two methods getarea()
 (pIr^2) and getperimeter() (2pI*r) which give
 both respective areas and perimeter'''
import math

class Circle:
  def __init__(self, radius):
    self.radius = radius

  def get_area(self):
    return math.pi * (self.radius ** 2)

  def get_perimeter(self):
    return 2 * math.pi * self.radius


circle = Circle(8)
print(circle.get_area())
print(circle.get_perimeter())
# Out:
# 201.06192982974676
# 50.26548245743669

# %%
'''write a program to create the following dataset using numpy and pandas.
sap id  fname   lname   subject   teacher    marks
use matplotlib/seaborn to draw visualization plots'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a numpy array with random data
data = np.random.randint(100000, 999999, size=(100, 6))

# Create a pandas DataFrame with column names
df = pd.DataFrame(data, columns=['sap id', 'fname', 'lname', 'subject', 'teacher', 'marks'])

# Print the first 5 rows of the DataFrame
print(df.head())

# Draw a histogram of marks using matplotlib
plt.hist(df['marks'])
plt.title('Histogram of Marks')
plt.xlabel('Marks')
plt.ylabel('Frequency')
plt.show()

# Draw a boxplot of marks by subject using seaborn
sns.boxplot(x='subject', y='marks', data=df)
plt.title('Boxplot of Marks by Subject')
plt.xlabel('Subject')
plt.ylabel('Marks')
plt.show()

# Draw a scatterplot of marks by teacher using seaborn
sns.scatterplot(x='teacher', y='marks', data=df)
plt.title('Scatterplot of Marks by Teacher')
plt.xlabel('Teacher')
plt.ylabel('Marks')
plt.show()
# Out:
#    sap id   fname   lname  subject  teacher   marks
# 0  322637  132443  593196   751277   684081  968791
# 1  598354  854336  511285   109753   356599  565214
# 2  221344  949264  913269   549974   103136  618706
# 3  430285  900980  750307   757231   458773  778877
# 4  782889  257488  870600   756081   237124  393312
